# %% [markdown]
# 介绍如何在pytorch环境下，使用FGSM算法攻击基于MNIST数据集预训练的CNN/MLP模型。运行该文件前，需要先运行指定文件生成对应的模型：
#
#     cd tutorials
#     python mnist_model_pytorch.py

# %% [markdown]
# Jupyter notebook中使用Anaconda中的环境需要单独配置，默认情况下使用的是系统默认的Python环境，以使用advbox环境为例。
# 首先在默认系统环境下执行以下命令，安装ipykernel。
#
#     conda install ipykernel
#     conda install -n advbox ipykernel
#
# 在advbox环境下激活，这样启动后就可以在界面上看到advbox了。
#
#     python -m ipykernel install --user --name advbox --display-name advbox

# %%
#调试开关
import logging
#logging.basicConfig(level=logging.INFO,format="%(filename)s[line:%(lineno)d] %(levelname)s %(message)s")
#logger=logging.getLogger(__name__)
import sys
import torch
import torchvision
from torchvision import datasets, transforms
from torch.autograd import Variable
import torch.utils.data.dataloader as Data
from advbox.adversary import Adversary
from advbox.attacks.gradient_method import FGSM
from advbox.models.pytorch import PytorchModel
from tutorials.mnist_model_pytorch import Net
# Out:
# train_data: torch.Size([60000, 28, 28])
# train_labels: torch.Size([60000])
# test_data: torch.Size([10000, 28, 28])

# %%
TOTAL_NUM = 500
pretrained_model="tutorials/mnist-pytorch/net.pth"
loss_func = torch.nn.CrossEntropyLoss()

#使用MNIST测试数据集 随机挑选TOTAL_NUM个
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('tutorials/mnist-pytorch/data', train=False, download=True, transform=transforms.Compose([
        transforms.ToTensor(),
    ])),
    batch_size=1, shuffle=True)

# Define what device we are using
logging.info("CUDA Available: {}".format(torch.cuda.is_available()))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the network
model = Net().to(device)

# Load the pretrained model
model.load_state_dict(torch.load(pretrained_model, map_location='cpu'))

# Set the model in evaluation mode. In this case this is for the Dropout layers
model.eval()

# advbox demo
m = PytorchModel(
    model, loss_func,(0, 1),
    channel_axis=1)

#实例化FGSM
attack = FGSM(m)
#设置攻击步长为0.1
attack_config = {"epsilons": 0.1}

# use test data to generate adversarial examples
total_count = 0
fooling_count = 0

for i, data in enumerate(test_loader):
    inputs, labels = data
    inputs, labels=inputs.numpy(),labels.numpy()

    total_count += 1
    adversary = Adversary(inputs, labels[0])

    # FGSM non-targeted attack
    adversary = attack(adversary, **attack_config)

    if adversary.is_successful():
        fooling_count += 1
        print(
            'attack success, original_label=%d, adversarial_label=%d, count=%d'
            % (labels, adversary.adversarial_label, total_count))

    else:
        print('attack failed, original_label=%d, count=%d' %
              (labels, total_count))

    if total_count >= TOTAL_NUM:
        print(
            "[TEST_DATASET]: fooling_count=%d, total_count=%d, fooling_rate=%f"
            % (fooling_count, total_count,
               float(fooling_count) / total_count))
        break
print("fgsm attack done")
# Out:
# cpu
# attack success, original_label=1, adversarial_label=4, count=1
# attack success, original_label=1, adversarial_label=4, count=2
# attack success, original_label=0, adversarial_label=6, count=3
# attack success, original_label=9, adversarial_label=4, count=4
# attack success, original_label=3, adversarial_label=7, count=5
# attack success, original_label=1, adversarial_label=7, count=6
# attack success, original_label=3, adversarial_label=8, count=7
# attack success, original_label=1, adversarial_label=7, count=8
# attack success, original_label=4, adversarial_label=9, count=9
# attack success, original_label=9, adversarial_label=4, count=10
# attack success, original_label=9, adversarial_label=7, count=11
# attack success, original_label=9, adversarial_label=3, count=12
# attack success, original_label=3, adversarial_label=8, count=13
# attack success, original_label=7, adversarial_label=3, count=14
# attack success, original_label=0, adversarial_label=7, count=15
# attack success, original_label=9, adversarial_label=8, count=16
# attack success, original_label=9, adversarial_label=4, count=17
# attack success, original_label=5, adversarial_label=7, count=18
# attack success, original_label=6, adversarial_label=4, count=19
# attack success, original_label=8, adversarial_label=3, count=20
# attack success, original_label=5, adversarial_label=9, count=21
# attack success, original_label=1, adversarial_label=7, count=22
# attack success, original_label=0, adversarial_label=9, count=23
# attack success, original_label=0, adversarial_label=7, count=24
# attack success, original_label=7, adversarial_label=9, count=25
# attack success, original_label=0, adversarial_label=9, count=26
# attack success, original_label=9, adversarial_label=4, count=27
# attack success, original_label=3, adversarial_label=5, count=28
# attack success, original_label=1, adversarial_label=5, count=29
# attack success, original_label=4, adversarial_label=8, count=30
# attack success, original_label=4, adversarial_label=7, count=31
# attack success, original_label=0, adversarial_label=5, count=32
# attack success, original_label=8, adversarial_label=3, count=33
# attack success, original_label=6, adversarial_label=8, count=34
# attack success, original_label=0, adversarial_label=7, count=35
# attack success, original_label=3, adversarial_label=8, count=36
# attack success, original_label=4, adversarial_label=1, count=37
# attack success, original_label=9, adversarial_label=7, count=38
# attack success, original_label=9, adversarial_label=4, count=39
# attack success, original_label=3, adversarial_label=8, count=40
# attack success, original_label=5, adversarial_label=3, count=41
# attack success, original_label=2, adversarial_label=8, count=42
# attack success, original_label=9, adversarial_label=4, count=43
# attack success, original_label=4, adversarial_label=7, count=44
# attack success, original_label=8, adversarial_label=3, count=45
# attack success, original_label=5, adversarial_label=3, count=46
# attack success, original_label=9, adversarial_label=4, count=47
# attack success, original_label=6, adversarial_label=0, count=48
# attack success, original_label=6, adversarial_label=0, count=49
# attack success, original_label=5, adversarial_label=9, count=50
# attack success, original_label=4, adversarial_label=9, count=51
# attack success, original_label=4, adversarial_label=7, count=52
# attack success, original_label=3, adversarial_label=7, count=53
# attack success, original_label=0, adversarial_label=5, count=54
# attack success, original_label=4, adversarial_label=6, count=55
# attack success, original_label=5, adversarial_label=3, count=56
# attack success, original_label=5, adversarial_label=3, count=57
# attack success, original_label=1, adversarial_label=8, count=58
# attack success, original_label=5, adversarial_label=3, count=59
# attack success, original_label=5, adversarial_label=6, count=60
# attack success, original_label=5, adversarial_label=9, count=61
# attack success, original_label=2, adversarial_label=3, count=62
# attack success, original_label=4, adversarial_label=8, count=63
# attack success, original_label=0, adversarial_label=5, count=64
# attack success, original_label=5, adversarial_label=9, count=65
# attack success, original_label=8, adversarial_label=5, count=66
# attack success, original_label=0, adversarial_label=2, count=67
# attack success, original_label=2, adversarial_label=3, count=68
# attack success, original_label=6, adversarial_label=0, count=69
# attack success, original_label=3, adversarial_label=8, count=70
# attack success, original_label=0, adversarial_label=5, count=71
# attack success, original_label=4, adversarial_label=9, count=72
# attack success, original_label=2, adversarial_label=3, count=73
# attack success, original_label=0, adversarial_label=5, count=74
# attack success, original_label=7, adversarial_label=9, count=75
# attack success, original_label=9, adversarial_label=4, count=76
# attack success, original_label=1, adversarial_label=4, count=77
# attack success, original_label=0, adversarial_label=8, count=78
# attack success, original_label=6, adversarial_label=8, count=79
# attack success, original_label=0, adversarial_label=9, count=80
# attack success, original_label=3, adversarial_label=5, count=81
# attack success, original_label=3, adversarial_label=8, count=82
# attack success, original_label=1, adversarial_label=7, count=83
# attack success, original_label=0, adversarial_label=9, count=84
# attack success, original_label=9, adversarial_label=3, count=85
# attack success, original_label=6, adversarial_label=8, count=86
# attack success, original_label=3, adversarial_label=5, count=87
# attack success, original_label=6, adversarial_label=0, count=88
# attack success, original_label=4, adversarial_label=7, count=89
# attack success, original_label=6, adversarial_label=5, count=90
# attack success, original_label=7, adversarial_label=3, count=91
# attack success, original_label=9, adversarial_label=7, count=92
# attack success, original_label=7, adversarial_label=3, count=93
# attack success, original_label=4, adversarial_label=7, count=94
# attack success, original_label=3, adversarial_label=5, count=95
# attack success, original_label=8, adversarial_label=3, count=96
# attack success, original_label=7, adversarial_label=3, count=97
# attack success, original_label=1, adversarial_label=7, count=98
# attack success, original_label=4, adversarial_label=8, count=99
# attack success, original_label=3, adversarial_label=8, count=100
# attack success, original_label=0, adversarial_label=9, count=101
# attack success, original_label=8, adversarial_label=3, count=102
# attack success, original_label=0, adversarial_label=8, count=103
# attack success, original_label=6, adversarial_label=8, count=104
# attack success, original_label=7, adversarial_label=3, count=105
# attack success, original_label=5, adversarial_label=3, count=106
# attack success, original_label=3, adversarial_label=5, count=107
# attack success, original_label=4, adversarial_label=5, count=108
# attack success, original_label=0, adversarial_label=2, count=109
# attack success, original_label=9, adversarial_label=4, count=110
# attack success, original_label=8, adversarial_label=9, count=111
# attack success, original_label=0, adversarial_label=9, count=112
# attack success, original_label=8, adversarial_label=5, count=113
# attack success, original_label=8, adversarial_label=3, count=114
# attack success, original_label=9, adversarial_label=4, count=115
# attack success, original_label=3, adversarial_label=5, count=116
# attack success, original_label=6, adversarial_label=8, count=117
# attack success, original_label=5, adversarial_label=3, count=118
# attack success, original_label=7, adversarial_label=9, count=119
# attack success, original_label=5, adversarial_label=3, count=120
# attack success, original_label=7, adversarial_label=3, count=121
# attack success, original_label=0, adversarial_label=8, count=122
# attack success, original_label=7, adversarial_label=3, count=123
# attack success, original_label=7, adversarial_label=3, count=124
# attack success, original_label=6, adversarial_label=0, count=125
# attack success, original_label=6, adversarial_label=5, count=126
# attack success, original_label=0, adversarial_label=5, count=127
# attack success, original_label=6, adversarial_label=4, count=128
# attack success, original_label=6, adversarial_label=0, count=129
# attack success, original_label=6, adversarial_label=8, count=130
# attack success, original_label=1, adversarial_label=7, count=131
# attack success, original_label=8, adversarial_label=3, count=132
# attack success, original_label=3, adversarial_label=9, count=133
# attack success, original_label=8, adversarial_label=2, count=134
# attack success, original_label=0, adversarial_label=1, count=135
# attack success, original_label=8, adversarial_label=3, count=136
# attack success, original_label=7, adversarial_label=9, count=137
# attack success, original_label=2, adversarial_label=3, count=138
# attack success, original_label=3, adversarial_label=8, count=139
# attack success, original_label=8, adversarial_label=3, count=140
# attack success, original_label=6, adversarial_label=8, count=141
# attack success, original_label=7, adversarial_label=9, count=142
# attack success, original_label=6, adversarial_label=8, count=143
# attack success, original_label=3, adversarial_label=7, count=144
# attack success, original_label=3, adversarial_label=9, count=145
# attack success, original_label=2, adversarial_label=1, count=146
# attack success, original_label=2, adversarial_label=3, count=147
# attack success, original_label=5, adversarial_label=8, count=148
# attack success, original_label=4, adversarial_label=9, count=149
# attack success, original_label=8, adversarial_label=5, count=150
# attack success, original_label=1, adversarial_label=4, count=151
# attack success, original_label=6, adversarial_label=8, count=152
# attack success, original_label=0, adversarial_label=6, count=153
# attack success, original_label=8, adversarial_label=3, count=154
# attack success, original_label=3, adversarial_label=8, count=155
# attack success, original_label=7, adversarial_label=5, count=156
# attack success, original_label=7, adversarial_label=9, count=157
# attack success, original_label=8, adversarial_label=3, count=158
# attack success, original_label=2, adversarial_label=3, count=159
# attack success, original_label=3, adversarial_label=5, count=160
# attack success, original_label=6, adversarial_label=0, count=161
# attack success, original_label=8, adversarial_label=3, count=162
# attack success, original_label=2, adversarial_label=3, count=163
# attack success, original_label=5, adversarial_label=8, count=164
# attack success, original_label=9, adversarial_label=7, count=165
# attack success, original_label=3, adversarial_label=5, count=166
# attack success, original_label=1, adversarial_label=7, count=167
# attack success, original_label=2, adversarial_label=1, count=168
# attack success, original_label=1, adversarial_label=2, count=169
# attack success, original_label=1, adversarial_label=7, count=170
# attack success, original_label=3, adversarial_label=8, count=171
# attack success, original_label=2, adversarial_label=3, count=172
# attack success, original_label=6, adversarial_label=8, count=173
# attack success, original_label=1, adversarial_label=7, count=174
# attack success, original_label=0, adversarial_label=7, count=175
# attack success, original_label=0, adversarial_label=7, count=176
# attack success, original_label=3, adversarial_label=7, count=177
# attack success, original_label=6, adversarial_label=5, count=178
# attack success, original_label=1, adversarial_label=7, count=179
# attack success, original_label=6, adversarial_label=8, count=180
# attack success, original_label=3, adversarial_label=5, count=181
# attack success, original_label=5, adversarial_label=9, count=182
# attack success, original_label=4, adversarial_label=7, count=183
# attack success, original_label=2, adversarial_label=7, count=184
# attack success, original_label=5, adversarial_label=2, count=185
# attack success, original_label=2, adversarial_label=7, count=186
# attack success, original_label=2, adversarial_label=3, count=187
# attack success, original_label=6, adversarial_label=0, count=188
# attack success, original_label=9, adversarial_label=4, count=189
# attack success, original_label=2, adversarial_label=3, count=190
# attack success, original_label=1, adversarial_label=7, count=191
# attack success, original_label=2, adversarial_label=1, count=192
# attack success, original_label=6, adversarial_label=8, count=193
# attack success, original_label=6, adversarial_label=0, count=194
# attack success, original_label=1, adversarial_label=7, count=195
# attack success, original_label=1, adversarial_label=7, count=196
# attack success, original_label=4, adversarial_label=9, count=197
# attack success, original_label=5, adversarial_label=3, count=198
# attack success, original_label=3, adversarial_label=5, count=199
# attack success, original_label=1, adversarial_label=7, count=200
# attack success, original_label=6, adversarial_label=0, count=201
# attack success, original_label=7, adversarial_label=3, count=202
# attack success, original_label=3, adversarial_label=5, count=203
# attack success, original_label=8, adversarial_label=3, count=204
# attack success, original_label=7, adversarial_label=3, count=205
# attack success, original_label=2, adversarial_label=3, count=206
# attack success, original_label=4, adversarial_label=7, count=207
# attack success, original_label=2, adversarial_label=1, count=208
# attack success, original_label=2, adversarial_label=3, count=209
# attack success, original_label=6, adversarial_label=0, count=210
# attack success, original_label=8, adversarial_label=3, count=211
# attack success, original_label=4, adversarial_label=8, count=212
# attack success, original_label=4, adversarial_label=8, count=213
# attack success, original_label=7, adversarial_label=9, count=214
# attack success, original_label=7, adversarial_label=2, count=215
# attack success, original_label=1, adversarial_label=7, count=216
# attack success, original_label=8, adversarial_label=3, count=217
# attack success, original_label=4, adversarial_label=7, count=218
# attack success, original_label=0, adversarial_label=9, count=219
# attack success, original_label=8, adversarial_label=3, count=220
# attack success, original_label=0, adversarial_label=9, count=221
# attack success, original_label=0, adversarial_label=6, count=222
# attack success, original_label=9, adversarial_label=4, count=223
# attack success, original_label=4, adversarial_label=8, count=224
# attack success, original_label=2, adversarial_label=3, count=225
# attack success, original_label=7, adversarial_label=3, count=226
# attack success, original_label=4, adversarial_label=3, count=227
# attack success, original_label=7, adversarial_label=3, count=228
# attack success, original_label=4, adversarial_label=7, count=229
# attack success, original_label=7, adversarial_label=3, count=230
# attack success, original_label=1, adversarial_label=7, count=231
# attack success, original_label=2, adversarial_label=7, count=232
# attack success, original_label=0, adversarial_label=9, count=233
# attack success, original_label=0, adversarial_label=5, count=234
# attack success, original_label=0, adversarial_label=9, count=235
# attack success, original_label=2, adversarial_label=3, count=236
# attack success, original_label=5, adversarial_label=8, count=237
# attack success, original_label=8, adversarial_label=3, count=238
# attack success, original_label=6, adversarial_label=5, count=239
# attack success, original_label=0, adversarial_label=5, count=240
# attack success, original_label=3, adversarial_label=5, count=241
# attack success, original_label=9, adversarial_label=4, count=242
# attack success, original_label=1, adversarial_label=7, count=243
# attack success, original_label=1, adversarial_label=8, count=244
# attack success, original_label=3, adversarial_label=5, count=245
# attack success, original_label=1, adversarial_label=7, count=246
# attack success, original_label=8, adversarial_label=3, count=247
# attack success, original_label=1, adversarial_label=7, count=248
# attack success, original_label=5, adversarial_label=3, count=249
# attack success, original_label=1, adversarial_label=4, count=250
# attack success, original_label=7, adversarial_label=3, count=251
# attack success, original_label=6, adversarial_label=8, count=252
# attack success, original_label=3, adversarial_label=5, count=253
# attack success, original_label=3, adversarial_label=9, count=254
# attack success, original_label=6, adversarial_label=8, count=255
# attack success, original_label=4, adversarial_label=2, count=256
# attack success, original_label=8, adversarial_label=3, count=257
# attack success, original_label=1, adversarial_label=7, count=258
# attack success, original_label=0, adversarial_label=9, count=259
# attack success, original_label=8, adversarial_label=3, count=260
# attack success, original_label=0, adversarial_label=5, count=261
# attack success, original_label=9, adversarial_label=7, count=262
# attack success, original_label=9, adversarial_label=5, count=263
# attack success, original_label=5, adversarial_label=3, count=264
# attack success, original_label=0, adversarial_label=5, count=265
# attack success, original_label=5, adversarial_label=3, count=266
# attack success, original_label=8, adversarial_label=3, count=267
# attack success, original_label=7, adversarial_label=9, count=268
# attack success, original_label=7, adversarial_label=3, count=269
# attack success, original_label=1, adversarial_label=4, count=270
# attack success, original_label=2, adversarial_label=3, count=271
# attack success, original_label=3, adversarial_label=5, count=272
# attack success, original_label=9, adversarial_label=4, count=273
# attack success, original_label=7, adversarial_label=3, count=274
# attack success, original_label=9, adversarial_label=7, count=275
# attack success, original_label=1, adversarial_label=7, count=276
# attack success, original_label=6, adversarial_label=0, count=277
# attack success, original_label=6, adversarial_label=0, count=278
# attack success, original_label=1, adversarial_label=7, count=279
# attack success, original_label=6, adversarial_label=5, count=280
# attack success, original_label=1, adversarial_label=4, count=281
# attack success, original_label=1, adversarial_label=7, count=282
# attack success, original_label=3, adversarial_label=9, count=283
# attack success, original_label=9, adversarial_label=4, count=284
# attack success, original_label=5, adversarial_label=3, count=285
# attack success, original_label=1, adversarial_label=7, count=286
# attack success, original_label=0, adversarial_label=4, count=287
# attack success, original_label=6, adversarial_label=8, count=288
# attack success, original_label=5, adversarial_label=9, count=289
# attack success, original_label=3, adversarial_label=5, count=290
# attack success, original_label=5, adversarial_label=6, count=291
# attack success, original_label=4, adversarial_label=8, count=292
# attack success, original_label=1, adversarial_label=7, count=293
# attack success, original_label=0, adversarial_label=2, count=294
# attack success, original_label=9, adversarial_label=3, count=295
# attack success, original_label=9, adversarial_label=4, count=296
# attack success, original_label=3, adversarial_label=8, count=297
# attack success, original_label=1, adversarial_label=7, count=298
# attack success, original_label=1, adversarial_label=7, count=299
# attack success, original_label=7, adversarial_label=9, count=300
# attack success, original_label=8, adversarial_label=3, count=301
# attack success, original_label=0, adversarial_label=9, count=302
# attack success, original_label=3, adversarial_label=5, count=303
# attack success, original_label=4, adversarial_label=7, count=304
# attack success, original_label=8, adversarial_label=3, count=305
# attack success, original_label=3, adversarial_label=9, count=306
# attack success, original_label=5, adversarial_label=3, count=307
# attack success, original_label=8, adversarial_label=3, count=308
# attack success, original_label=4, adversarial_label=8, count=309
# attack success, original_label=6, adversarial_label=8, count=310
# attack success, original_label=5, adversarial_label=6, count=311
# attack success, original_label=5, adversarial_label=3, count=312
# attack success, original_label=3, adversarial_label=5, count=313
# attack success, original_label=3, adversarial_label=2, count=314
# attack success, original_label=2, adversarial_label=8, count=315
# attack success, original_label=0, adversarial_label=5, count=316
# attack success, original_label=3, adversarial_label=8, count=317
# attack success, original_label=3, adversarial_label=7, count=318
# attack success, original_label=0, adversarial_label=3, count=319
# attack success, original_label=9, adversarial_label=3, count=320
# attack success, original_label=1, adversarial_label=7, count=321
# attack success, original_label=2, adversarial_label=1, count=322
# attack success, original_label=6, adversarial_label=0, count=323
# attack success, original_label=6, adversarial_label=0, count=324
# attack success, original_label=2, adversarial_label=3, count=325
# attack success, original_label=9, adversarial_label=7, count=326
# attack success, original_label=3, adversarial_label=8, count=327
# attack success, original_label=1, adversarial_label=8, count=328
# attack success, original_label=9, adversarial_label=7, count=329
# attack success, original_label=6, adversarial_label=0, count=330
# attack success, original_label=8, adversarial_label=3, count=331
# attack success, original_label=4, adversarial_label=2, count=332
# attack success, original_label=0, adversarial_label=8, count=333
# attack success, original_label=8, adversarial_label=2, count=334
# attack success, original_label=3, adversarial_label=5, count=335
# attack success, original_label=7, adversarial_label=1, count=336
# attack success, original_label=5, adversarial_label=8, count=337
# attack success, original_label=1, adversarial_label=4, count=338
# attack success, original_label=1, adversarial_label=7, count=339
# attack success, original_label=3, adversarial_label=5, count=340
# attack success, original_label=5, adversarial_label=3, count=341
# attack success, original_label=2, adversarial_label=3, count=342
# attack success, original_label=9, adversarial_label=4, count=343
# attack success, original_label=5, adversarial_label=3, count=344
# attack success, original_label=0, adversarial_label=5, count=345
# attack success, original_label=3, adversarial_label=5, count=346
# attack success, original_label=7, adversarial_label=3, count=347
# attack success, original_label=6, adversarial_label=0, count=348
# attack success, original_label=0, adversarial_label=6, count=349
# attack success, original_label=0, adversarial_label=9, count=350
# attack success, original_label=1, adversarial_label=8, count=351
# attack success, original_label=3, adversarial_label=8, count=352
# attack success, original_label=9, adversarial_label=7, count=353
# attack success, original_label=1, adversarial_label=7, count=354
# attack success, original_label=0, adversarial_label=7, count=355
# attack success, original_label=1, adversarial_label=4, count=356
# attack success, original_label=1, adversarial_label=4, count=357
# attack success, original_label=9, adversarial_label=4, count=358
# attack success, original_label=8, adversarial_label=3, count=359
# attack success, original_label=7, adversarial_label=3, count=360
# attack success, original_label=9, adversarial_label=8, count=361
# attack success, original_label=2, adversarial_label=3, count=362
# attack success, original_label=7, adversarial_label=9, count=363
# attack success, original_label=8, adversarial_label=3, count=364
# attack success, original_label=9, adversarial_label=4, count=365
# attack success, original_label=2, adversarial_label=3, count=366
# attack success, original_label=7, adversarial_label=3, count=367
# attack success, original_label=8, adversarial_label=3, count=368
# attack success, original_label=8, adversarial_label=5, count=369
# attack success, original_label=9, adversarial_label=4, count=370
# attack success, original_label=4, adversarial_label=7, count=371
# attack success, original_label=8, adversarial_label=3, count=372
# attack success, original_label=2, adversarial_label=3, count=373
# attack success, original_label=5, adversarial_label=3, count=374
# attack success, original_label=7, adversarial_label=3, count=375
# attack success, original_label=6, adversarial_label=8, count=376
# attack success, original_label=1, adversarial_label=7, count=377
# attack success, original_label=9, adversarial_label=4, count=378
# attack success, original_label=8, adversarial_label=3, count=379
# attack success, original_label=5, adversarial_label=3, count=380
# attack success, original_label=0, adversarial_label=6, count=381
# attack success, original_label=1, adversarial_label=7, count=382
# attack success, original_label=2, adversarial_label=3, count=383
# attack success, original_label=7, adversarial_label=3, count=384
# attack success, original_label=2, adversarial_label=3, count=385
# attack success, original_label=9, adversarial_label=3, count=386
# attack success, original_label=5, adversarial_label=9, count=387
# attack success, original_label=6, adversarial_label=8, count=388
# attack success, original_label=6, adversarial_label=0, count=389
# attack success, original_label=4, adversarial_label=9, count=390
# attack success, original_label=1, adversarial_label=7, count=391
# attack success, original_label=4, adversarial_label=3, count=392
# attack success, original_label=0, adversarial_label=7, count=393
# attack success, original_label=2, adversarial_label=3, count=394
# attack success, original_label=4, adversarial_label=5, count=395
# attack success, original_label=8, adversarial_label=3, count=396
# attack success, original_label=0, adversarial_label=6, count=397
# attack success, original_label=7, adversarial_label=3, count=398
# attack success, original_label=2, adversarial_label=8, count=399
# attack success, original_label=0, adversarial_label=9, count=400
# attack success, original_label=0, adversarial_label=9, count=401
# attack success, original_label=7, adversarial_label=3, count=402
# attack success, original_label=5, adversarial_label=9, count=403
# attack success, original_label=8, adversarial_label=5, count=404
# attack success, original_label=7, adversarial_label=3, count=405
# attack success, original_label=3, adversarial_label=8, count=406
# attack success, original_label=1, adversarial_label=4, count=407
# attack success, original_label=4, adversarial_label=7, count=408
# attack success, original_label=8, adversarial_label=3, count=409
# attack success, original_label=0, adversarial_label=9, count=410
# attack success, original_label=6, adversarial_label=8, count=411
# attack success, original_label=1, adversarial_label=7, count=412
# attack success, original_label=8, adversarial_label=3, count=413
# attack success, original_label=1, adversarial_label=7, count=414
# attack success, original_label=4, adversarial_label=9, count=415
# attack success, original_label=7, adversarial_label=3, count=416
# attack success, original_label=1, adversarial_label=7, count=417
# attack success, original_label=3, adversarial_label=9, count=418
# attack success, original_label=1, adversarial_label=7, count=419
# attack success, original_label=0, adversarial_label=9, count=420
# attack success, original_label=1, adversarial_label=7, count=421
# attack success, original_label=0, adversarial_label=9, count=422
# attack success, original_label=4, adversarial_label=9, count=423
# attack success, original_label=7, adversarial_label=3, count=424
# attack success, original_label=7, adversarial_label=9, count=425
# attack success, original_label=0, adversarial_label=4, count=426
# attack success, original_label=8, adversarial_label=0, count=427
# attack success, original_label=0, adversarial_label=8, count=428
# attack success, original_label=9, adversarial_label=5, count=429
# attack success, original_label=8, adversarial_label=5, count=430
# attack success, original_label=5, adversarial_label=3, count=431
# attack success, original_label=2, adversarial_label=3, count=432
# attack success, original_label=9, adversarial_label=4, count=433
# attack success, original_label=3, adversarial_label=7, count=434
# attack success, original_label=6, adversarial_label=8, count=435
# attack success, original_label=4, adversarial_label=8, count=436
# attack success, original_label=8, adversarial_label=4, count=437
# attack success, original_label=9, adversarial_label=3, count=438
# attack success, original_label=8, adversarial_label=3, count=439
# attack success, original_label=0, adversarial_label=9, count=440
# attack success, original_label=3, adversarial_label=5, count=441
# attack success, original_label=5, adversarial_label=9, count=442
# attack success, original_label=3, adversarial_label=7, count=443
# attack success, original_label=6, adversarial_label=5, count=444
# attack success, original_label=5, adversarial_label=3, count=445
# attack success, original_label=0, adversarial_label=9, count=446
# attack success, original_label=8, adversarial_label=0, count=447
# attack success, original_label=1, adversarial_label=7, count=448
# attack success, original_label=9, adversarial_label=7, count=449
# attack success, original_label=1, adversarial_label=3, count=450
# attack success, original_label=8, adversarial_label=2, count=451
# attack success, original_label=1, adversarial_label=8, count=452
# attack success, original_label=6, adversarial_label=8, count=453
# attack success, original_label=2, adversarial_label=3, count=454
# attack success, original_label=0, adversarial_label=9, count=455
# attack success, original_label=8, adversarial_label=3, count=456
# attack success, original_label=1, adversarial_label=8, count=457
# attack success, original_label=1, adversarial_label=7, count=458
# attack success, original_label=3, adversarial_label=9, count=459
# attack success, original_label=3, adversarial_label=5, count=460
# attack success, original_label=7, adversarial_label=2, count=461
# attack success, original_label=7, adversarial_label=5, count=462
# attack success, original_label=7, adversarial_label=9, count=463
# attack success, original_label=7, adversarial_label=3, count=464
# attack success, original_label=6, adversarial_label=5, count=465
# attack success, original_label=8, adversarial_label=3, count=466
# attack success, original_label=7, adversarial_label=1, count=467
# attack success, original_label=3, adversarial_label=5, count=468
# attack success, original_label=1, adversarial_label=7, count=469
# attack success, original_label=8, adversarial_label=3, count=470
# attack success, original_label=6, adversarial_label=0, count=471
# attack success, original_label=7, adversarial_label=9, count=472
# attack success, original_label=4, adversarial_label=3, count=473
# attack success, original_label=2, adversarial_label=7, count=474
# attack success, original_label=6, adversarial_label=0, count=475
# attack success, original_label=3, adversarial_label=5, count=476
# attack success, original_label=8, adversarial_label=3, count=477
# attack success, original_label=7, adversarial_label=3, count=478
# attack success, original_label=0, adversarial_label=9, count=479
# attack success, original_label=7, adversarial_label=3, count=480
# attack success, original_label=9, adversarial_label=4, count=481
# attack success, original_label=1, adversarial_label=7, count=482
# attack success, original_label=5, adversarial_label=3, count=483
# attack success, original_label=7, adversarial_label=9, count=484
# attack success, original_label=6, adversarial_label=8, count=485
# attack success, original_label=9, adversarial_label=4, count=486
# attack success, original_label=6, adversarial_label=0, count=487
# attack success, original_label=0, adversarial_label=7, count=488
# attack success, original_label=1, adversarial_label=3, count=489
# attack success, original_label=9, adversarial_label=4, count=490
# attack success, original_label=7, adversarial_label=3, count=491
# attack success, original_label=7, adversarial_label=9, count=492
# attack success, original_label=3, adversarial_label=7, count=493
# attack success, original_label=6, adversarial_label=8, count=494
# attack success, original_label=6, adversarial_label=5, count=495
# attack success, original_label=9, adversarial_label=4, count=496
# attack success, original_label=6, adversarial_label=0, count=497
# attack success, original_label=3, adversarial_label=7, count=498
# attack success, original_label=7, adversarial_label=3, count=499
# attack success, original_label=6, adversarial_label=0, count=500
# [TEST_DATASET]: fooling_count=500, total_count=500, fooling_rate=1.000000
# fgsm attack done
